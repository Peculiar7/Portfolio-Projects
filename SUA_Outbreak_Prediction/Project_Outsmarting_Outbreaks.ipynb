# %% [markdown]
# # Project Title: Outsmarting Outbreaks

# %% [markdown]
# ## AIM: To predict the total number of climate-sensitive waterborne disease outbreak in Tanzania

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from scipy.spatial import cKDTree

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomTreesEmbedding
from warnings import simplefilter
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

import random
import joblib
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import Normalizer, StandardScaler, RobustScaler, OneHotEncoder

# %%
SEED = 2023
random.seed(SEED)
np.random.seed(SEED)

# %%
# Load datasets
train = pd.read_csv("Train.csv")
test = pd.read_csv("Test.csv")
toilets = pd.read_csv("toilets.csv")
waste_management = pd.read_csv("waste_management.csv")
water_sources = pd.read_csv("water_sources.csv")

# %%
# Combine train and test datasets for consistent preprocessing
hospital_data = pd.concat([train, test])

# %%
# Drop unnecessary columns from supplementary datasets
for df in [toilets, waste_management, water_sources]:
    df.drop(columns=['Year', 'Month'], inplace=True)

# %%
# Rename columns for clarity
def rename_columns(df, prefix):
    for col in df.columns:
        if col not in ['Month_Year_lat_lon', 'lat_lon']:
            df.rename(columns={col: f"{prefix}_{col}"}, inplace=True)

rename_columns(toilets, "toilet")
rename_columns(waste_management, "waste")
rename_columns(water_sources, "water")

# %%
# Fill missing values in the 'Total' column
hospital_data['Total'].fillna(0, inplace=True)

# %%
# Drop rows with missing latitude and longitude in water sources
water_sources.dropna(subset=['water_Transformed_Latitude'], inplace=True)

# %%
def find_nearest(hospital_df, location_df, lat_col, lon_col, id_col):
    # Create a cKDTree for efficient nearest neighbour search
    tree = cKDTree(location_df[[lat_col, lon_col]].values)
    nearest = {}
    # Loop through each hospital and find the nearest site in location_df
    for _, row in hospital_df.iterrows():
        _, idx = tree.query([row['Transformed_Latitude'], row['Transformed_Longitude']])
        nearest[row['ID']] = location_df.iloc[idx][id_col]
    return nearest

# %%
# Ensure unique identifier columns exist in all supplementary datasets
for df, prefix in [(toilets, 'toilet'), (waste_management, 'waste'), (water_sources, 'water')]:
    df[f"{prefix}_Month_Year_lat_lon"] = (
        df[f"{prefix}_Month_Year"] + '_' +
        df[f"{prefix}_Transformed_Latitude"].astype(str) + '_' +
        df[f"{prefix}_Transformed_Longitude"].astype(str)
    )

# %%
# Merge datasets with nearest locations
merged_data = hospital_data.copy()
datasets = [
    (toilets, 'toilet', 'toilet_Month_Year_lat_lon'),
    (waste_management, 'waste', 'waste_Month_Year_lat_lon'),
    (water_sources, 'water', 'water_Month_Year_lat_lon'),
]

# %%
for df, prefix, id_col in datasets:
    nearest = find_nearest(merged_data, df, f"{prefix}_Transformed_Latitude", f"{prefix}_Transformed_Longitude", id_col)
    nearest_df = pd.DataFrame(list(nearest.items()), columns=['ID', id_col])
    merged_data = merged_data.merge(nearest_df, on="ID").merge(df, on=id_col)

# %%
merged_data.shape
# Out:
# (29332, 135)

# %% [markdown]
# ## Start modeling

# %%
# Split merged data into train and test sets
train_df = merged_data[merged_data['Year'] < 2023]
test_df = merged_data[merged_data['Year'] == 2023]

# %%
# Specify the target column
target_column = 'Total'

# Feature and target split
X = train_df.drop(columns=[target_column, 'ID', 'Location'])  # Exclude unnecessary columns
y = train_df[target_column]

# %%
print('mean of target per year :')
display(train_df.groupby(['ID', 'Year'])[target_column].max().reset_index().groupby('Year')[target_column].mean())
# Out:
# mean of target per year :
# Year
# 2019    18.295832
# 2020    15.540424
# 2021    13.049686
# 2022    10.775961
# Name: Total, dtype: float64

# %% [markdown]
# ### Data Preprocessing

# %%
NBR_FOLDS = 10
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import QuantileTransformer


def preprocess(dt_train, dt_test, mode = 'max', one_hot = False, tar_red = 3, dis = None, training_year = 2022, extra_ftrs = False):

    if dis is not None:
        dt_train = dt_train[dt_train['Disease'] == dis]
    dt_train_old = dt_train[dt_train['Year']==training_year-1].reset_index(drop = True)
    dt_train = dt_train[dt_train['Year']==training_year].reset_index(drop = True)


    
    # make the model more conservative by reducing the target values to follow the same bias per year : (2019 : 18), (2020 : 15), ..., (2023 : 7)
    # 2019  :  18.295832
    # 2020  :  15.540424
    # 2021  :  13.049686
    # 2022  :  10.775961
    dt_train.loc[dt_train[target_column]>tar_red, target_column] -= tar_red
    dt_train_old.loc[dt_train_old[target_column]>2*tar_red, target_column] -= 2*tar_red



    # handling samples with the same id :
    # features are the same per id for each year,but the target is different sometimes, 
    # it is advisable in this case to not train a model with the same input and different outputs,
    # so we will also make the output unique and select the mean or max target per id.
    ll = len(dt_train)
    if mode == 'mean':
        tar = dt_train.groupby(['ID', 'Year'])[target_column].mean()
    elif mode == 'max':
        tar = dt_train.groupby(['ID', 'Year'])[target_column].max()
    else:
        print('mode is not defined')
        raise Exception
    dt_train = dt_train.groupby(['ID', 'Year']).last().reset_index()
    dt_train[target_column] = tar.values
    print('dt_train :', ll, '->', len(dt_train))
    
    
    
    ll = len(dt_train_old)
    if mode == 'mean':
        tar = dt_train_old.groupby(['ID', 'Year'])[target_column].mean()
    elif mode == 'max':
        tar = dt_train_old.groupby(['ID', 'Year'])[target_column].max()
    else:
        print('mode is not defined')
        raise Exception
    dt_train_old = dt_train_old.groupby(['ID', 'Year']).last().reset_index()
    dt_train_old[target_column] = tar.values
    print('dt_train :', ll, '->', len(dt_train))

    # lgbm can be trained directly with categorical columns : object -> category
    for c in dt_train.dtypes[dt_train.dtypes=='object'].index:
        if c in  [target_column, 'ID']:
            continue;
        dt_train_old[c] = dt_train_old[c].astype('category')
        dt_train[c] = dt_train[c].astype('category')
        dt_test[c] = dt_test[c].astype('category')

 
    dt_features = [i for i in dt_train.columns if i not in [target_column, 'ID', 'Location']]
    dt_features = [i for i in dt_features if 'Latitude' not in i and 'Longitude' not in i]

    dt_label = target_column
    
    num_cols = [i for i in dt_features if dt_train[i].dtype not in ['object', 'category']]
    cat_cols = [i for i in dt_features if dt_train[i].dtype in ['object', 'category']]
    
    
    if extra_ftrs:
        NBR_FTRS = 20
        
        NBR_KM = NBR_FTRS
        for ncl in range(2,NBR_KM):
            cls = KMeans(n_clusters=ncl, random_state = 0)
            cls.fit(pd.concat([dt_train_old[num_cols], dt_train[num_cols], dt_test[num_cols]]))
            dt_train['kmeans_cluster'+str(ncl)] = cls.predict(dt_train[num_cols])
            dt_test['kmeans_cluster'+str(ncl)] = cls.predict(dt_test[num_cols])
            dt_train_old['kmeans_cluster'+str(ncl)] = cls.predict(dt_train_old[num_cols])

        NBR_PCA = NBR_FTRS
        pca = PCA(n_components=NBR_PCA, random_state = 0)
        pca.fit(pd.concat([dt_train_old[num_cols], dt_train[num_cols], dt_test[num_cols]]))
        dt_train[['pca_cluster'+str(ncl) for ncl in range(NBR_PCA)]] = pca.transform(dt_train[num_cols])
        dt_test[['pca_cluster'+str(ncl) for ncl in range(NBR_PCA)]] = pca.transform(dt_test[num_cols])
        dt_train_old[['pca_cluster'+str(ncl) for ncl in range(NBR_PCA)]] = pca.transform(dt_train_old[num_cols])

        random_tree = RandomTreesEmbedding(n_estimators=NBR_FTRS, max_depth=1, random_state=0)
        random_tree.fit(pd.concat([dt_train_old[num_cols], dt_train[num_cols], dt_test[num_cols]]))
        trn_trans = random_tree.transform(dt_train[num_cols]).toarray()
        NBR_TREE = trn_trans.shape[1]
        dt_train[['random_tree_cluster'+str(ncl) for ncl in range(NBR_TREE)]] = trn_trans
        dt_test[['random_tree_cluster'+str(ncl) for ncl in range(NBR_TREE)]] = random_tree.transform(dt_test[num_cols]).toarray()
        dt_train_old[['random_tree_cluster'+str(ncl) for ncl in range(NBR_TREE)]] = random_tree.transform(dt_train_old[num_cols]).toarray()

        num_cols += ['kmeans_cluster'+str(ncl) for ncl in range(2,NBR_KM)] + ['pca_cluster'+str(ncl) for ncl in range(NBR_PCA)] + ['random_tree_cluster'+str(ncl) for ncl in range(NBR_TREE)]
    
    dt_features = cat_cols + num_cols

    
    if one_hot:
        cat_cols = [i for i in dt_features if i not in num_cols]

        enc = OneHotEncoder()
        enc_cat = enc.fit_transform(pd.concat([dt_train[cat_cols], dt_test[cat_cols]])).toarray()

        dt_train_old[[f'enc_cat{i}' for i in range(enc_cat.shape[1])]] = enc.transform(dt_train_old[cat_cols]).toarray()
        dt_train[[f'enc_cat{i}' for i in range(enc_cat.shape[1])]] = enc_cat[:len(dt_train)]
        dt_test[[f'enc_cat{i}' for i in range(enc_cat.shape[1])]] = enc_cat[len(dt_train):]

        dt_features = num_cols + [f'enc_cat{i}' for i in range(enc_cat.shape[1])]
        num_cols = dt_features
    
    # row-wise scaling
    scaler = Normalizer()
    scaler.fit(pd.concat([dt_train[num_cols], dt_test[num_cols]]))
    dt_train_old[num_cols] = scaler.transform(dt_train_old[num_cols])
    dt_train[num_cols] = scaler.transform(dt_train[num_cols])
    dt_test[num_cols] = scaler.transform(dt_test[num_cols])


    return dt_train, dt_test, dt_features, dt_label, dt_train_old

# %% [markdown]
# ### Model training

# %%
#from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.linear_model import TweedieRegressor, HuberRegressor, SGDRegressor
def train_and_get_sub(dt_train, dt_test, dt_features, dt_label, dt_train_old = None, model_name = 'lgb'):

    skf = StratifiedKFold(n_splits=NBR_FOLDS)
    for fold, (train_indicies, valid_indicies) in enumerate(skf.split(X=dt_train[dt_features],
                                                                      y = dt_train['Location'].astype(str) + dt_train['Disease'].astype(str))):
        dt_train.loc[valid_indicies, "kfold"] = fold
    
    oof = np.zeros(len(dt_train))
    preds = np.zeros(len(dt_test))

    for fold in range(NBR_FOLDS):
        print(fold)
        train     = dt_train[dt_train['kfold'] !=fold].reset_index(drop = True)
        val       = dt_train[dt_train['kfold'] ==fold].reset_index(drop=True)
        cat_features = [i for i in dt_features if train[i].dtype == 'category']
        
        if dt_train_old is not None:
            train = pd.concat([train, dt_train_old]).astype(train.dtypes)

        train_dataset = lgb.Dataset(train[dt_features], train[dt_label])
        eval_dataset  = lgb.Dataset(val[dt_features], val[dt_label])


        model = lgb.train(
                        params = lgb_params,
                        train_set = train_dataset,
                        num_boost_round = 100000,
                        valid_sets = [train_dataset, eval_dataset],
                        callbacks = [lgb.early_stopping(200), lgb.log_evaluation(500)],
                    )

        oof[dt_train['kfold'] ==fold] += model.predict(val[dt_features])
        preds += model.predict(dt_test[dt_features])

    preds /= NBR_FOLDS

    mae = mean_absolute_error(dt_train[dt_label], oof)
    print(f"Mean Absolute Error (MAE): {mae}")
    mae = mean_absolute_error(dt_train[dt_label], np.floor(oof.clip(0)))
    print(f"Mean Absolute Error (MAE) after postprocessing: {mae}")
    
    dt_train['oof'] = oof
    

    sub = dt_test[['ID']].copy()
    sub['Predicted_Total'] = preds
    return sub, dt_train

# %% [markdown]
# ### Evaluation and Submission

# %%
lgb_params = {
    'objective': 'mae',
    'metric' : 'mae',
    'learning_rate': 0.03,
    'max_depth': 5,
    'seed': 42,
    'n_jobs': 14,
    'boosting':'goss',
    'top_rate':0.3,
    'verbose' : -1,
}

dt_train = train_df.copy()
dt_test = test_df.copy()
dt_train, dt_test, dt_features, dt_label, dt_train_old = preprocess(dt_train, dt_test, extra_ftrs = True)
sub1, dt_train1 = train_and_get_sub(dt_train, dt_test, dt_features, dt_label)

dt_train = train_df.copy()
dt_test = test_df.copy()
dt_train, dt_test, dt_features, dt_label, dt_train_old = preprocess(dt_train, dt_test, extra_ftrs = True)
sub1_old, dt_train1_old = train_and_get_sub(dt_train, dt_test, dt_features, dt_label, dt_train_old)

bst_w, bst_score = -1, np.inf
for w in np.linspace(0, 1):
    tmp_oof = w * dt_train1['oof'] + (1-w) * dt_train1_old['oof']
    score = mean_absolute_error(dt_train1['Total'], tmp_oof)
    if score < bst_score:
        bst_w, bst_score = w, score

dt_train1['oof'] = bst_w * dt_train1['oof'] + (1-bst_w) * dt_train1_old['oof']
sub1['Predicted_Total'] = bst_w * sub1['Predicted_Total'] + (1-bst_w) * sub1_old['Predicted_Total']

print('MAE score ens :', mean_absolute_error(dt_train1['Total'], dt_train1['oof']))
print('MAE score ens clipped :', mean_absolute_error(dt_train1['Total'], np.floor(dt_train1['oof'].clip(0))))


diss = ['Typhoid', 'Diarrhea', 'Malaria', 'Schistosomiasis', 'Intestinal Worms']
subs_local, local_trns = [], []
for dis in diss:
    
    dt_train = train_df.copy()
    dt_test = test_df.copy()
    dt_train, dt_test, dt_features, dt_label, dt_train_old = preprocess(dt_train, dt_test, dis = dis)
    _sub, _dt_train = train_and_get_sub(dt_train, dt_test, dt_features, dt_label)
    
    dt_train = train_df.copy()
    dt_test = test_df.copy()
    dt_train, dt_test, dt_features, dt_label, dt_train_old = preprocess(dt_train, dt_test, dis = dis)
    _sub_old, _dt_train_old = train_and_get_sub(dt_train, dt_test, dt_features, dt_label, dt_train_old)

    
    bst_w, bst_score = -1, np.inf
    for w in np.linspace(0, 1):
        tmp_oof = w * _dt_train['oof'] + (1-w) * _dt_train_old['oof']
        score = mean_absolute_error(dt_train['Total'], tmp_oof)
        if score < bst_score:
            bst_w, bst_score = w, score
    _dt_train['oof'] = bst_w * _dt_train['oof'] + (1-bst_w) * _dt_train_old['oof']
    _sub['Predicted_Total'] = bst_w * _sub['Predicted_Total'] + (1-bst_w) * _sub_old['Predicted_Total']
    subs_local.append(_sub)
    local_trns.append(_dt_train)
sub2 = _sub.copy()
for i, dis in enumerate(diss):
    sub2.loc[dt_test['Disease'] == dis, 'Predicted_Total'] = subs_local[i].loc[dt_test['Disease'] == dis, 'Predicted_Total']
    print(dis, 'mae score :', mean_absolute_error(local_trns[i]['Total'], local_trns[i]['oof']))


w = 0.3
sub = sub1.copy()
sub.loc[dt_test['Disease'].isin(diss), 'Predicted_Total'] = w*sub1.loc[dt_test['Disease'].isin(diss), 'Predicted_Total'] + (1-w)*sub2.loc[dt_test['Disease'].isin(diss), 'Predicted_Total']

sub['Predicted_Total'] = np.floor(sub['Predicted_Total'].values.clip(0))
# Out:
# dt_train : 7194 -> 3852
# dt_train : 5973 -> 3852
# C:\Users\USER\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# 0
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.35489	valid_1's l1: 4.82287
# [1000]	training's l1: 5.95035	valid_1's l1: 4.56423
# [1500]	training's l1: 5.75789	valid_1's l1: 4.39959
# [2000]	training's l1: 5.60883	valid_1's l1: 4.30157
# [2500]	training's l1: 5.29236	valid_1's l1: 4.04819
# Early stopping, best iteration is:
# [2504]	training's l1: 5.29189	valid_1's l1: 4.04791
# 1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.23949	valid_1's l1: 5.13898
# [1000]	training's l1: 5.79674	valid_1's l1: 4.87059
# [1500]	training's l1: 5.53362	valid_1's l1: 4.68675
# [2000]	training's l1: 5.43501	valid_1's l1: 4.64234
# [2500]	training's l1: 5.38367	valid_1's l1: 4.61603
# [3000]	training's l1: 5.32073	valid_1's l1: 4.56834
# Early stopping, best iteration is:
# [3046]	training's l1: 5.31975	valid_1's l1: 4.56647
# 2
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.0194	valid_1's l1: 5.12146
# [1000]	training's l1: 5.77609	valid_1's l1: 5.03984
# [1500]	training's l1: 5.40428	valid_1's l1: 5.07227
# Early stopping, best iteration is:
# [1351]	training's l1: 5.52828	valid_1's l1: 4.98964
# 3
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 5.94878	valid_1's l1: 9.66191
# [1000]	training's l1: 5.51965	valid_1's l1: 9.3007
# [1500]	training's l1: 5.32426	valid_1's l1: 9.16525
# [2000]	training's l1: 5.11908	valid_1's l1: 9.06328
# [2500]	training's l1: 5.02849	valid_1's l1: 9.00169
# [3000]	training's l1: 4.95795	valid_1's l1: 8.96069
# Early stopping, best iteration is:
# [3177]	training's l1: 4.92522	valid_1's l1: 8.9264
# 4
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 5.8301	valid_1's l1: 10.5776
# [1000]	training's l1: 5.37259	valid_1's l1: 10.1789
# [1500]	training's l1: 5.18693	valid_1's l1: 10.0345
# [2000]	training's l1: 5.07145	valid_1's l1: 9.92162
# [2500]	training's l1: 4.93954	valid_1's l1: 9.76927
# [3000]	training's l1: 4.84779	valid_1's l1: 9.65202
# [3500]	training's l1: 4.77117	valid_1's l1: 9.59896
# Early stopping, best iteration is:
# [3613]	training's l1: 4.76068	valid_1's l1: 9.59413
# 5
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.0016	valid_1's l1: 8.72393
# [1000]	training's l1: 5.73418	valid_1's l1: 8.44427
# [1500]	training's l1: 5.40423	valid_1's l1: 8.09656
# [2000]	training's l1: 5.21542	valid_1's l1: 7.8333
# [2500]	training's l1: 5.12457	valid_1's l1: 7.73272
# Early stopping, best iteration is:
# [2651]	training's l1: 5.10837	valid_1's l1: 7.72775
# 6
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.04633	valid_1's l1: 7.48209
# [1000]	training's l1: 5.493	valid_1's l1: 6.97885
# [1500]	training's l1: 5.34409	valid_1's l1: 6.84925
# [2000]	training's l1: 5.22377	valid_1's l1: 6.77014
# [2500]	training's l1: 5.16251	valid_1's l1: 6.73598
# [3000]	training's l1: 5.06211	valid_1's l1: 6.72035
# [3500]	training's l1: 5.02363	valid_1's l1: 6.70567
# Early stopping, best iteration is:
# [3752]	training's l1: 5.00025	valid_1's l1: 6.69634
# 7
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.2198	valid_1's l1: 4.78627
# [1000]	training's l1: 5.77959	valid_1's l1: 4.62856
# [1500]	training's l1: 5.56145	valid_1's l1: 4.58538
# Early stopping, best iteration is:
# [1746]	training's l1: 5.50881	valid_1's l1: 4.57292
# 8
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 5.91784	valid_1's l1: 5.56142
# [1000]	training's l1: 5.4942	valid_1's l1: 5.31849
# Early stopping, best iteration is:
# [1228]	training's l1: 5.41767	valid_1's l1: 5.26836
# 9
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.47324	valid_1's l1: 5.27895
# [1000]	training's l1: 5.87992	valid_1's l1: 5.07787
# Early stopping, best iteration is:
# [859]	training's l1: 5.97883	valid_1's l1: 5.07105
# Mean Absolute Error (MAE): 6.145141922804321
# Mean Absolute Error (MAE) after postprocessing: 6.098130841121495
# dt_train : 7194 -> 3852
# dt_train : 5973 -> 3852
# C:\Users\USER\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# 0
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.93546	valid_1's l1: 4.76819
# [1000]	training's l1: 6.65332	valid_1's l1: 4.57059
# [1500]	training's l1: 6.36879	valid_1's l1: 4.38685
# [2000]	training's l1: 6.24904	valid_1's l1: 4.35538
# [2500]	training's l1: 6.07854	valid_1's l1: 4.27248
# [3000]	training's l1: 5.98534	valid_1's l1: 4.19973
# [3500]	training's l1: 5.91537	valid_1's l1: 4.16543
# Early stopping, best iteration is:
# [3688]	training's l1: 5.89096	valid_1's l1: 4.14916
# 1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.90089	valid_1's l1: 5.1801
# [1000]	training's l1: 6.66227	valid_1's l1: 5.0024
# [1500]	training's l1: 6.47442	valid_1's l1: 4.93107
# [2000]	training's l1: 6.24065	valid_1's l1: 4.77699
# [2500]	training's l1: 6.07131	valid_1's l1: 4.68592
# [3000]	training's l1: 5.97272	valid_1's l1: 4.64109
# [3500]	training's l1: 5.92405	valid_1's l1: 4.61583
# Early stopping, best iteration is:
# [3535]	training's l1: 5.91765	valid_1's l1: 4.60945
# 2
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 7.00562	valid_1's l1: 5.20362
# [1000]	training's l1: 6.6524	valid_1's l1: 4.99888
# [1500]	training's l1: 6.22414	valid_1's l1: 4.77647
# [2000]	training's l1: 6.08997	valid_1's l1: 4.74495
# Early stopping, best iteration is:
# [1935]	training's l1: 6.10165	valid_1's l1: 4.73916
# 3
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6
# 8
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.66942	valid_1's l1: 7.54958
# Early stopping, best iteration is:
# [316]	training's l1: 6.70335	valid_1's l1: 7.53978
# 9
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [280]	training's l1: 7.29533	valid_1's l1: 2.28909
# Mean Absolute Error (MAE): 7.474507803027628
# Mean Absolute Error (MAE) after postprocessing: 7.4672897196261685
# dt_train : 1958 -> 642
# dt_train : 1629 -> 642
# C:\Users\USER\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# 0
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [153]	training's l1: 9.98844	valid_1's l1: 8.62152
# 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [166]	training's l1: 9.38159	valid_1's l1: 12.179
# 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [54]	training's l1: 12.5662	valid_1's l1: 12.0542
# 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [276]	training's l1: 9.20716	valid_1's l1: 16.7263
# 4
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 8.7729	valid_1's l1: 18.5092
# [1000]	training's l1: 8.26149	valid_1's l1: 18.0876
# Early stopping, best iteration is:
# [1032]	training's l1: 8.237	valid_1's l1: 18.0459
# 5
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 9.53367	valid_1's l1: 8.26588
# [1000]	training's l1: 9.09788	valid_1's l1: 7.8739
# [1500]	training's l1: 8.87995	valid_1's l1: 7.75977
# [2000]	training's l1: 8.64134	valid_1's l1: 7.622
# Early stopping, best iteration is:
# [2040]	training's l1: 8.62576	valid_1's l1: 7.6165
# 6
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 9.69069	valid_1's l1: 7.60283
# Early stopping, best iteration is:
# [345]	training's l1: 9.89456	valid_1's l1: 7.54799
# 7
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [55]	training's l1: 12.9907	valid_1's l1: 6.1092
# 8
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 9.16708	valid_1's l1: 11.2027
# Early stopping, best iteration is:
# [609]	training's l1: 9.02183	valid_1's l1: 11.1046
# 9
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 8.82273	valid_1's l1: 14.0933
# Early stopping, best iteration is:
# [650]	training's l1: 8.63509	valid_1's l1: 14.0313
# Mean Absolute Error (MAE): 11.40053615944749
# Mean Absolute Error (MAE) after postprocessing: 11.362928348909657
# dt_train : 1958 -> 642
# dt_train : 1629 -> 642
# C:\Users\USER\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# 0
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 10.1159	valid_1's l1: 9.07801
# [1000]	training's l1: 9.61561	valid_1's l1: 8.81991
# [1500]	training's l1: 9.27888	valid_1's l1: 8.50978
# Early stopping, best iteration is:
# [1397]	training's l1: 9.30855	valid_1's l1: 8.46192
# 1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 10.1997	valid_1's l1: 12.7218
# Early stopping, best iteration is:
# [460]	training's l1: 10.2772	valid_1's l1: 12.6603
# 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [104]	training's l1: 11.7171	valid_1's l1: 11.6048
# 3
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 9.79823	valid_1's l1: 16.3988
# Early stopping, best iteration is:
# [306]	training's l1: 10.2881	valid_1's l1: 16.3916
# 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [81]	training's l1: 11.768	valid_1's l1: 20.2911
# 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [160]	training's l1: 11.1131	valid_1's l1: 8.33239
# 6
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 10.1432	valid_1's l1: 7.1603
# Early stopping, best iteration is:
# [452]	training's l1: 10.1993	valid_1's l1: 7.09223
# 7
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [39]	training's l1: 15.0361	valid_1's l1: 5.82684
# 8
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 9.94697	valid_1's l1: 11.5034
# [1000]	training's l1: 9.58724	valid_1's l1: 11.4151
# [1500]	training's l1: 9.2566	valid_1's l1: 11.1728
# [2000]	training's l1: 9.01214	valid_1's l1: 11.0507
# [2500]	training's l1: 8.868	valid_1's l1: 11.0179
# Early stopping, best iteration is:
# [2341]	training's l1: 8.90973	valid_1's l1: 11.0111
# 9
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1:
# 8
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 1.42337	valid_1's l1: 0.80532
# [1000]	training's l1: 1.37609	valid_1's l1: 0.765503
# [1500]	training's l1: 1.35903	valid_1's l1: 0.75447
# Early stopping, best iteration is:
# [1498]	training's l1: 1.35905	valid_1's l1: 0.754459
# 9
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 1.45811	valid_1's l1: 0.659232
# Early stopping, best iteration is:
# [540]	training's l1: 1.45759	valid_1's l1: 0.658194
# Mean Absolute Error (MAE): 1.350930049356669
# Mean Absolute Error (MAE) after postprocessing: 1.367601246105919
# dt_train : 655 -> 642
# dt_train : 543 -> 642
# C:\Users\USER\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# 0
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 1.30574	valid_1's l1: 0.429419
# [1000]	training's l1: 1.30302	valid_1's l1: 0.419032
# Early stopping, best iteration is:
# [1236]	training's l1: 1.30037	valid_1's l1: 0.417187
# 1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 1.31594	valid_1's l1: 0.454304
# [1000]	training's l1: 1.30987	valid_1's l1: 0.445276
# Early stopping, best iteration is:
# [982]	training's l1: 1.31002	valid_1's l1: 0.445203
# 2
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 1.25469	valid_1's l1: 1.33897
# [1000]	training's l1: 1.25302	valid_1's l1: 1.33302
# [1500]	training's l1: 1.25097	valid_1's l1: 1.32751
# Early stopping, best iteration is:
# [1685]	training's l1: 1.25019	valid_1's l1: 1.31731
# 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [55]	training's l1: 1.26533	valid_1's l1: 1.35792
# 4
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 1.13582	valid_1's l1: 3.392
# [1000]	training's l1: 1.13401	valid_1's l1: 3.38493
# Early stopping, best iteration is:
# [860]	training's l1: 1.13438	valid_1's l1: 3.38418
# 5
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 1.21704	valid_1's l1: 1.96724
# [1000]	training's l1: 1.21561	valid_1's l1: 1.96309
# Early stopping, best iteration is:
# [1139]	training's l1: 1.21516	valid_1's l1: 1.96128
# 6
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 1.30378	valid_1's l1: 0.486603
# [1000]	training's l1: 1.29968	valid_1's l1: 0.473873
# [1500]	training's l1: 1.29897	valid_1's l1: 0.472542
# [2000]	training's l1: 1.29834	valid_1's l1: 0.469803
# [2500]	training's l1: 1.29786	valid_1's l1: 0.468184
# [3000]	training's l1: 1.29705	valid_1's l1: 0.470949
# Early stopping, best iteration is:
# [2938]	training's l1: 1.29733	valid_1's l1: 0.467499
# 7
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 1.20911	valid_1's l1: 2.10905
# [1000]	training's l1: 1.20812	valid_1's l1: 2.10424
# [1500]	training's l1: 1.20692	valid_1's l1: 2.09906
# [2000]	training's l1: 1.20516	valid_1's l1: 2.09497
# Early stopping, best iteration is:
# [1879]	training's l1: 1.20538	valid_1's l1: 2.09491
# 8
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [64]	training's l1: 1.32494	valid_1's l1: 0.740132
# 9
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [34]	training's l1: 1.35091	valid_1's l1: 0.676604
# Mean Absolute Error (MAE): 1.283559655471128
# Mean Absolute Error (MAE) after postprocessing: 1.2959501557632398
# dt_train : 654 -> 642
# dt_train : 543 -> 642
# C:\Users\USER\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# 0
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 7.08917	valid_1's l1: 8.72548
# [1000]	training's l1: 6.7895	valid_1's l1: 8.6685
# Early stopping, best iteration is:
# [1079]	training's l1: 6.75016	valid_1's l1: 8.66252
# 1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 7.22117	valid_1's l1: 7.6777
# Early stopping, best iteration is:
# [761]	training's l1: 6.99698	valid_1's l1: 7.63773
# 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [75]	training's l1: 8.15198	valid_1's l1: 11.5303
# 3
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 7.02839	valid_1's l1: 9.00263
# Early stopping, best iteration is:
# [451]	training's l1: 7.08529	valid_1's l1: 8.98514
# 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [120]	training's l1: 7.64997	valid_1's l1: 12.3699
# 5
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.85752	valid_1's l1: 10.9921
# [1000]	training's l1: 6.55608	valid_1's l1: 10.8878
# [1500]	training's l1: 6.43958	valid_1's l1: 10.8519
# [2000]	training's l1: 6.35466	valid_1's l1: 10.8188
# Early stopping, best iteration is:
# [2149]	training's l1: 6.33534	valid_1's l1: 10.8079
# 6
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 7.34788	valid_1's l1: 9.67901
# [1000]	training's l1: 6.78133	valid_1's l1: 8.83836
# [1500]	training's l1: 6.60174	valid_1's l1: 8.79978
# Early stopping, best iteration is:
# [1657]	training's l1: 6.57431	valid_1's l1: 8.79256
# 7
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 7.33367	valid_1's l1: 5.58449
# Early stopping, best iteration is:
# [332]	training's l1: 7.51902	valid_1's l1: 5.55562
# 8
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [206]	training's l1: 7.33513	valid_1's l1: 8.13988
# 9
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [60]	training's l1: 8.952	valid_1's l1: 7.385
# Mean Absolute Error (MAE): 8.984058550403835
# Mean Absolute Error (MAE) after postprocessing: 8.96417445482866
# dt_train : 654 -> 642
# dt_train : 543 -> 642
# C:\Users\USER\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# 0
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [139]	training's l1: 9.08238	valid_1's l1: 8.92617
# 1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 8.49006	valid_1's l1: 7.83177
# Early stopping, best iteration is:
# [308]	training's l1: 8.79445	valid_1's l1: 7.78221
# 2
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [206]	training's l1: 8.9196	valid_1's l1: 10.834
# 3
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [49]	training's l1: 10.3769	valid_1's l1: 9.73401
# 4
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [229]	training's l1: 8.69968	valid_1's l1: 11.9297
# 5
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 8.38631	valid_1's l1: 11.3928
# Early stopping, best iteration is:
# [786]	training's l1: 8.0789	valid_1's l1: 11.2263
# 6
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 8.60535	valid_1's l1: 9.83681
# [1000]	training's l1: 8.17044	valid_1's l1: 9.62284
# Early stopping, best iteration is:
# [1191]	training's l1: 8.04173	valid_1's l1: 9.32464
# 7
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 8.73611	valid_1's l1: 6.19226
# Early stopping, best iteration is:
# [580]	training's l1: 8.60537	valid_1's l1: 6.12043
# 8
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 8.62304	valid_1's l1: 8.66455
# [1000]	training's l1: 8.21494	valid_1's l1: 8.54399
# Early stopping, best iteration is:
# [1238]	training's l1: 8.05251	valid_1's l1: 8.44335
# 9
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [67]	training's l1: 9.90123	valid_1's l1: 7.22847
# Mean Absolute Error (MAE): 9.15243538378144
# Mean Absolute Error (MAE) after postprocessing: 9.121495327102803
# Typhoid mae score : 7.474507803027628
# Diarrhea mae score : 11.383916355666223
# Malaria mae score : 5.34093339220889
# Schistosomiasis mae score : 1.283559655471128
# Intestinal Worms mae score : 8.968298463518789

# %%
test_preds = sub['Predicted_Total'].values.copy()

# %%
lgb_params = {
    'objective': 'mae',
    'metric' : 'mae',
    'learning_rate': 0.03,
    'max_depth': 5,
    'seed': 42,
    'n_jobs': 14,
    'boosting':'goss',
    'top_rate':0.3,
    'verbose' : -1,
}

diss = ['Typhoid', 'Diarrhea', 'Malaria', 'Schistosomiasis', 'Intestinal Worms']


dt_train = train_df.copy()
dt_test = test_df.copy()
dt_train, dt_test, dt_features, dt_label, dt_train_old = preprocess(dt_train, dt_test, extra_ftrs = True)
pl = dt_test.reset_index(drop = True).copy()
pl['Total'] = test_preds.copy()
skf = StratifiedKFold(n_splits=NBR_FOLDS)
for fold, (train_indicies, valid_indicies) in enumerate(skf.split(X=pl[dt_features], y = pl['Location'].astype(str) + pl['Disease'].astype(str))):
    pl.loc[valid_indicies, "kfold"] = fold
sub1, dt_train1 = train_and_get_sub(pl, dt_test, dt_features, dt_label, dt_train)

dt_train = train_df.copy()
dt_test = test_df.copy()
dt_train, dt_test, dt_features, dt_label, dt_train_old = preprocess(dt_train, dt_test, extra_ftrs = True)
pl = dt_test.reset_index(drop = True).copy()
pl['Total'] = test_preds.copy()
skf = StratifiedKFold(n_splits=NBR_FOLDS)
for fold, (train_indicies, valid_indicies) in enumerate(skf.split(X=pl[dt_features], y = pl['Location'].astype(str) + pl['Disease'].astype(str))):
    pl.loc[valid_indicies, "kfold"] = fold
sub1_old, dt_train1_old = train_and_get_sub(pl, dt_test, dt_features, dt_label, 
                                           pd.concat([dt_train, dt_train_old]).reset_index(drop = True))


bst_w, bst_score = -1, np.inf
for w in np.linspace(0, 1):
    tmp_oof = w * dt_train1['oof'] + (1-w) * dt_train1_old['oof']
    score = mean_absolute_error(dt_train1['Total'], tmp_oof)
    if score < bst_score:
        bst_w, bst_score = w, score

dt_train1['oof'] = bst_w * dt_train1['oof'] + (1-bst_w) * dt_train1_old['oof']
sub1['Predicted_Total'] = bst_w * sub1['Predicted_Total'] + (1-bst_w) * sub1_old['Predicted_Total']

print('MAE score ens :', mean_absolute_error(dt_train1['Total'], dt_train1['oof']))
print('MAE score ens clipped :', mean_absolute_error(dt_train1['Total'], np.floor(dt_train1['oof'].clip(0))))

subs_local, local_trns = [], []
for dis in diss:
    
    dt_train = train_df.copy()
    dt_test = test_df.copy()
    dt_train, dt_test, dt_features, dt_label, dt_train_old = preprocess(dt_train, dt_test, dis = dis)
    pl = dt_test.reset_index(drop = True).copy()
    pl['Total'] = test_preds.copy()
    pl = pl[pl['Disease']==dis].reset_index(drop = True)
    skf = StratifiedKFold(n_splits=NBR_FOLDS)
    for fold, (train_indicies, valid_indicies) in enumerate(skf.split(X=pl[dt_features], y = pl['Location'].astype(str))):
        pl.loc[valid_indicies, "kfold"] = fold
    _sub, _dt_train = train_and_get_sub(pl, dt_test, dt_features, dt_label, dt_train)


    dt_train = train_df.copy()
    dt_test = test_df.copy()
    dt_train, dt_test, dt_features, dt_label, dt_train_old = preprocess(dt_train, dt_test, dis = dis)
    pl = dt_test.reset_index(drop = True).copy()
    pl['Total'] = test_preds.copy()
    pl = pl[pl['Disease']==dis].reset_index(drop = True)
    skf = StratifiedKFold(n_splits=NBR_FOLDS)
    for fold, (train_indicies, valid_indicies) in enumerate(skf.split(X=pl[dt_features], y = pl['Location'].astype(str))):
        pl.loc[valid_indicies, "kfold"] = fold
    _sub_old, _dt_train_old = train_and_get_sub(pl, dt_test, dt_features, dt_label, pd.concat([dt_train, dt_train_old]).reset_index(drop = True))

    
    bst_w, bst_score = -1, np.inf
    for w in np.linspace(0, 1):
        tmp_oof = w * _dt_train['oof'] + (1-w) * _dt_train_old['oof']
        score = mean_absolute_error(_dt_train['Total'], tmp_oof)
        if score < bst_score:
            bst_w, bst_score = w, score
    _dt_train['oof'] = bst_w * _dt_train['oof'] + (1-bst_w) * _dt_train_old['oof']
    _sub['Predicted_Total'] = bst_w * _sub['Predicted_Total'] + (1-bst_w) * _sub_old['Predicted_Total']
    subs_local.append(_sub)
    local_trns.append(_dt_train)
sub2 = _sub.copy()
for i, dis in enumerate(diss):
    sub2.loc[dt_test['Disease'] == dis, 'Predicted_Total'] = subs_local[i].loc[dt_test['Disease'] == dis, 'Predicted_Total']
    print(dis, 'mae score :', mean_absolute_error(local_trns[i]['Total'], local_trns[i]['oof']))

w = 0.3
sub = sub1.copy()
sub.loc[dt_test['Disease'].isin(diss), 'Predicted_Total'] = w*sub1.loc[dt_test['Disease'].isin(diss), 'Predicted_Total'] + (1-w)*sub2.loc[dt_test['Disease'].isin(diss), 'Predicted_Total']

sub['Predicted_Total'] = np.floor(sub['Predicted_Total'].clip(0))

sub.to_csv('submission1.csv', index = False)
sub.loc[dt_test['Disease'] == 'Cholera', 'Predicted_Total'] = 0
sub.loc[dt_test['Disease'] == 'Dysentery', 'Predicted_Total'] = 0
sub.to_csv('submission1.csv', index = False)
# Out:
# dt_train : 7194 -> 3852
# dt_train : 5973 -> 3852
# 0
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 3.52151	valid_1's l1: 1.51662
# [1000]	training's l1: 3.06187	valid_1's l1: 1.02338
# [1500]	training's l1: 2.89641	valid_1's l1: 0.855807
# [2000]	training's l1: 2.78733	valid_1's l1: 0.712489
# [2500]	training's l1: 2.76761	valid_1's l1: 0.684099
# [3000]	training's l1: 2.74124	valid_1's l1: 0.647743
# [3500]	training's l1: 2.71524	valid_1's l1: 0.614549
# [4000]	training's l1: 2.68466	valid_1's l1: 0.587934
# [4500]	training's l1: 2.6652	valid_1's l1: 0.570981
# [5000]	training's l1: 2.64537	valid_1's l1: 0.558615
# [5500]	training's l1: 2.63312	valid_1's l1: 0.545854
# [6000]	training's l1: 2.62153	valid_1's l1: 0.536758
# [6500]	training's l1: 2.609	valid_1's l1: 0.526887
# Early stopping, best iteration is:
# [6571]	training's l1: 2.60799	valid_1's l1: 0.525612
# 1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 3.43036	valid_1's l1: 1.26144
# [1000]	training's l1: 3.0048	valid_1's l1: 0.832713
# [1500]	training's l1: 2.89763	valid_1's l1: 0.716163
# [2000]	training's l1: 2.83557	valid_1's l1: 0.656838
# [2500]	training's l1: 2.77428	valid_1's l1: 0.592245
# [3000]	training's l1: 2.73975	valid_1's l1: 0.555693
# [3500]	training's l1: 2.71547	valid_1's l1: 0.542082
# [4000]	training's l1: 2.68851	valid_1's l1: 0.525342
# [4500]	training's l1: 2.66182	valid_1's l1: 0.51937
# Early stopping, best iteration is:
# [4335]	training's l1: 2.66971	valid_1's l1: 0.518923
# 2
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 3.39043	valid_1's l1: 1.23179
# [1000]	training's l1: 3.10738	valid_1's l1: 0.954466
# [1500]	training's l1: 2.93567	valid_1's l1: 0.797006
# [2000]	training's l1: 2.81533	valid_1's l1: 0.655962
# [2500]	training's l1: 2.75694	valid_1's l1: 0.604536
# [3000]	training's l1: 2.71254	valid_1's l1: 0.557154
# [3500]	training's l1: 2.68145	valid_1's l1: 0.532718
# [4000]	training's l1: 2.65909	valid_1's l1: 0.519698
# [4500]	training's l1: 2.64813	valid_1's l1: 0.509304
-> 642
# dt_train : 543 -> 642
# 0
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 3.86354	valid_1's l1: 0.0889476
# Early stopping, best iteration is:
# [587]	training's l1: 3.85047	valid_1's l1: 0.0813719
# 1
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [244]	training's l1: 3.91964	valid_1's l1: 0.201511
# 2
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 3.89285	valid_1's l1: 0.209068
# [1000]	training's l1: 3.80095	valid_1's l1: 0.103029
# Early stopping, best iteration is:
# [1079]	training's l1: 3.79561	valid_1's l1: 0.0995013
# 3
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 3.8411	valid_1's l1: 0.172597
# [1000]	training's l1: 3.7865	valid_1's l1: 0.153043
# Early stopping, best iteration is:
# [1062]	training's l1: 3.78106	valid_1's l1: 0.151118
# 4
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 3.8785	valid_1's l1: 0.0947143
# Early stopping, best iteration is:
# [726]	training's l1: 3.87215	valid_1's l1: 0.091452
# 5
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 3.85622	valid_1's l1: 0.0675578
# Early stopping, best iteration is:
# [651]	training's l1: 3.83858	valid_1's l1: 0.0623447
# 6
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 3.86466	valid_1's l1: 0.0709707
# [1000]	training's l1: 3.83157	valid_1's l1: 0.0651774
# Early stopping, best iteration is:
# [867]	training's l1: 3.83824	valid_1's l1: 0.0613651
# 7
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [225]	training's l1: 3.88183	valid_1's l1: 0.235248
# 8
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 3.85153	valid_1's l1: 0.159745
# [1000]	training's l1: 3.81278	valid_1's l1: 0.143451
# [1500]	training's l1: 3.77726	valid_1's l1: 0.125138
# Early stopping, best iteration is:
# [1587]	training's l1: 3.76524	valid_1's l1: 0.118283
# 9
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 3.83435	valid_1's l1: 0.0957542
# [1000]	training's l1: 3.79169	valid_1's l1: 0.0848983
# Early stopping, best iteration is:
# [889]	training's l1: 3.79977	valid_1's l1: 0.0726854
# Mean Absolute Error (MAE): 0.1175502564418249
# Mean Absolute Error (MAE) after postprocessing: 0.1483050847457627
# dt_train : 656 -> 642
# dt_train : 543 -> 642
# 0
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.6399	valid_1's l1: 0.0793054
# Early stopping, best iteration is:
# [589]	training's l1: 4.63606	valid_1's l1: 0.0766081
# 1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.57742	valid_1's l1: 0.067525
# Early stopping, best iteration is:
# [667]	training's l1: 4.49798	valid_1's l1: 0.0600553
# 2
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.69831	valid_1's l1: 0.101654
# [1000]	training's l1: 4.65193	valid_1's l1: 0.0826037
# [1500]	training's l1: 4.60158	valid_1's l1: 0.0782634
# Early stopping, best iteration is:
# [1421]	training's l1: 4.6164	valid_1's l1: 0.0738728
# 3
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.63743	valid_1's l1: 0.0962979
# Early stopping, best iteration is:
# [519]	training's l1: 4.63697	valid_1's l1: 0.0951926
# 4
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.67903	valid_1's l1: 0.0844709
# Early stopping, best iteration is:
# [623]	training's l1: 4.60401	valid_1's l1: 0.0651337
# 5
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.63147	valid_1's l1: 0.13898
# Early stopping, best iteration is:
# [408]	training's l1: 4.68799	valid_1's l1: 0.113485
# 6
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [120]	training's l1: 4.62651	valid_1's l1: 0.0466698
# 7
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.55685	valid_1's l1: 0.124206
# [1000]	training's l1: 4.54083	valid_1's l1: 0.120435
# Early stopping, best iteration is:
# [1122]	training's l1: 4.5364	valid_1's l1: 0.111631
# 8
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.56459	valid_1's l1: 0.0957819
# Early stopping, best iteration is:
# [741]	training's l1: 4.55265	valid_1's l1: 0.0918032
# 9
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.6592	valid_1's l1: 0.110778
# [1000]	training's l1: 4.65897	valid_1's l1: 0.110486
# [1500]	training's l1: 4.65784	valid_1's l1: 0.107393
# [2000]	training's l1: 4.64431	valid_1's l1: 0.0887116
# [2500]	training's l1: 4.52642	valid_1's l1: 0.072913
# Early stopping, best iteration is:
# [2366]	training's l1: 4.59418	valid_1's l1: 0.0665896
# Mean Absolute Error (MAE): 0.08010673744020097
# Mean Absolute Error (MAE) after postprocessing: 0.09745762711864407
# dt_train : 1958 -> 642
# dt_train : 1629 -> 642
# 0
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 5.41814	valid_1's l1: 0.923344
# [1000]	training's l1: 5.12552	valid_1's l1: 0.920258
# Early stopping, best iteration is:
# [843]	training's l1: 5.25377	valid_1's l1: 0.844144
# 1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 5.35055	valid_1's l1: 0.835345
# [1000]	training's l1: 5.12153	valid_1's l1: 0.758471
# Early stopping, best iteration is:
# [1087]	training's l1: 5.09207	valid_1's l1: 0.752157
# 2
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 5.37827	valid_1's l1: 0.910794
# [1000]	training's l1: 5.05116	valid_1's l1: 0.856249
# [1500]	training's l1: 4.96036	valid_1's l1: 0.826767
# [2000]	training's l1: 4.88922	valid_1's l1: 0.808748
# [2500]	training's l1: 4.85087	valid_1's l1: 0.799886
# Early stopping, best iteration is:
# [2511]	training's l1: 4.84955	valid_1's l1: 0.798214
# 3
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 5.27715	valid_1's l1: 0.539784
# [1000]	training's l1: 5.03363	valid_1's l1: 0.498508
# [1500]	training's l1: 4.94005	valid_1's l1: 0.494377
# Early stopping, best iteration is:
# [1308]	training's l1: 4.98121	valid_1's l1: 0.488396
# 4
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 5.35068	valid_1's l1: 0.427112
# [1000]	training's l1: 5.14463	valid_1's l1: 0.385378
# [1500]	training's l1: 4.99896	valid_1's l1: 0.381908
# Early stopping, best iteration is:
# [1482]	training's l1: 5.00112	valid_1's l1: 0.379993
# 5
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 5.37318	valid_1's l1: 0.408243
# Early stopping, best iteration is:
# [737]	training's l1: 5.20986	valid_1's l1: 0.39108
# 6
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 5.19067	valid_1's l1: 0.398468
# Early stopping, best iteration is:
# [669]	training's l1: 5.13447	valid_1's l1: 0.38946
# 7
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 5.33921	valid_1's l1: 0.427895
# [1000]	training's l1: 5.14508	valid_1's l1: 0.423859
# Early stopping, best iteration is:
# [836]	training's l1: 5.19722	valid_1's l1: 0.418482
# 8
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 5.29348	valid_1's l1: 0.569231
# [1000]	training's l1: 5.1589	valid_1's l1: 0.530632
# Early stopping, best iteration is:
# [1033]	training's l1: 5.15554	valid_1's l1: 0.528031
# 9
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 5.34217	valid_1's l1: 0.419125
# [1000]	training's l1: 5.12435	valid_1's l1: 0.391796
# [1500]	training's l1: 5.04526	valid_1's l1: 0.367051
# Early stopping, best iteration is:
# [1460]	training's l1: 5.04868	valid_1's l1: 0.364911
# Mean Absolute Error (MAE): 0.5357381237906736
# Mean Absolute Error (MAE) after postprocessing: 0.6257062146892656
# dt_train : 1958 -> 642
# dt_train : 1629 -> 642
# 0
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 7.42266	valid_1's l1: 1.367
# [1000]	training's l1: 6.96634	valid_1's l1: 1.01823
# Early stopping, best iteration is:
# [1009]	training's l1: 6.9524	valid_1's l1: 1.00837
# 1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 7.35632	valid_1's l1: 0.905039
# [1000]	training's l1: 6.90486	valid_1's l1: 0.824889
# [1500]	training's l1: 6.77765	valid_1's l1: 0.802962
# Early stopping, best iteration is:
# [1355]	training's l1: 6.81389	valid_1's l1: 0.79711
# 2
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 7.57761	valid_1's l1: 0.751541
# Early stopping, best iteration is:
# [366]	training's l1: 7.75428	valid_1's l1: 0.727347
# 3
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 7.58084	valid_1's l1: 0.805484
# [1000]	training's l1: 7.17794	valid_1's l1: 0.737328
# [1500]	training's l1: 6.89181	valid_1's l1: 0.641796
# [2000]	training's l1: 6.72641	valid_1's l1: 0.576563
# Early stopping, best iteration is:
# [2256]	training's l1: 6.67419	valid_1's l1: 0.559828
# 4
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 7.57856	valid_1's l1: 0.618132
# Early stopping, best iteration is:
# [629]	training's l1: 7.44942	valid_1's l1: 0.571432
# 5
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 7.26347	valid_1's l1: 0.463247
# Early stopping, best iteration is:
# [325]	training's l1: 7.43712	valid_1's l1: 0.422353
# 6
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 7.27925	valid_1's l1: 0.480701
# [1000]	training's l1: 6.89366	valid_1's l1: 0.387228
# Early stopping, best iteration is:
# [1174]	training's l1: 6.77823	valid_1's l1: 0.371724
# 7
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [248]	training's l1: 7.98535	valid_1's l1: 0.484085
# 8
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 7.28387	valid_1's l1: 1.01812
# Early stopping, best iteration is:
# [388]	training's l1: 7.50003	valid_1's l1: 0.994895
# 9
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [190]	training's l1: 7.91873	valid_1's l1: 0.445057
# Mean Absolute Error (MAE): 0.6379894603892846
# Mean Absolute Error (MAE) after postprocessing: 0.7076271186440678
# dt_train : 2616 -> 642
# dt_train : 2172 -> 642
# 0
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 2.46524	valid_1's l1: 0.598983
# [1000]	training's l1: 2.36859	valid_1's l1: 0.50585
# Early stopping, best iteration is:
# [938]	training's l1: 2.37282	valid_1's l1: 0.502031
# 1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 2.44266	valid_1's l1: 0.448738
# Early stopping, best iteration is:
# [772]	training's l1: 2.3835	valid_1's l1: 0.422477
# 2
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 2.46697	valid_1's l1: 0.518574
# Early stopping, best iteration is:
# [758]	training's l1: 2.3997	valid_1's l1: 0.489592
# 3
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 2.44551	valid_1's l1: 0.570827
# [1000]	training's l1: 2.34208	valid_1's l1: 0.538461
# [1500]	training's l1: 2.29324	valid_1's l1: 0.511636
# [2000]	training's l1: 2.27207	valid_1's l1: 0.504617
# Early stopping, best iteration is:
# [2091]	training's l1: 2.26614	valid_1's l1: 0.501012
# 4
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 2.46126	valid_1's l1: 0.573614
# Early stopping, best iteration is:
# [472]	training's l1: 2.47231	valid_1's l1: 0.568753
# 5
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 2.48646	valid_1's l1: 0.505656
# [1000]	training's l1: 2.3887	valid_1's l1: 0.482812
# [1500]	training's l1: 2.31021	valid_1's l1: 0.463572
# [2000]	training's l1: 2.26976	valid_1's l1: 0.457845
# [2500]	training's l1: 2.24939	valid_1's l1: 0.449342
# Early stopping, best iteration is:
# [2708]	training's l1: 2.24154	valid_1's l1: 0.445384
# 6
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 2.47818	valid_1's l1: 0.408794
# [1000]	training's l1: 2.38677	valid_1's l1: 0.369797
# Early stopping, best iteration is:
# [1137]	training's l1: 2.36456	valid_1's l1: 0.358407
# 7
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 2.4972	valid_1's l1: 0.318785
# [1000]	training's l1: 2.41465	valid_1's l1: 0.298021
# [1500]	training's l1: 2.36932	valid_1's l1: 0.287601
# [2000]	training's l1: 2.33209	valid_1's l1: 0.285133
# Early stopping, best iteration is:
# [2210]	training's l1: 2.31403	valid_1's l1: 0.280998
# 8
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 2.45307	valid_1's l1: 0.270118
# Early stopping, best iteration is:
# [509]	training's l1: 2.45185	valid_1's l1: 0.269697
# 9
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 2.46996	valid_1's l1: 0.294971
# Early stopping, best iteration is:
# [325]	training's l1: 2.52243	valid_1's l1: 0.280645
# Mean Absolute Error (MAE): 0.41228590531316966
# Mean Absolute Error (MAE) after postprocessing: 0.5296610169491526
# dt_train : 2616 -> 642
# dt_train : 2172 -> 642
# 0
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [104]	training's l1: 4.5915	valid_1's l1: 0.798594
# 1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.13443	valid_1's l1: 0.52837
# Early stopping, best iteration is:
# [583]	training's l1: 4.06225	valid_1's l1: 0.503704
# 2
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.03189	valid_1's l1: 0.565159
# [1000]	training's l1: 3.8108	valid_1's l1: 0.511134
# Early stopping, best iteration is:
# [1115]	training's l1: 3.77887	valid_1's l1: 0.506775
# 3
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.02318	valid_1's l1: 0.584121
# [1000]	training's l1: 3.79818	valid_1's l1: 0.541315
# Early stopping, best iteration is:
# [1199]	training's l1: 3.75075	valid_1's l1: 0.521151
# 4
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.0166	valid_1's l1: 0.412047
# Early stopping, best iteration is:
# [750]	training's l1: 3.90901	valid_1's l1: 0.379723
# 5
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.09099	valid_1's l1: 0.439274
# [1000]	training's l1: 3.92501	valid_1's l1: 0.400225
# [1500]	training's l1: 3.83461	valid_1's l1: 0.377286
# [2000]	training's l1: 3.76775	valid_1's l1: 0.372394
# Early stopping, best iteration is:
# [1835]	training's l1: 3.79622	valid_1's l1: 0.367891
# 6
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.23772	valid_1's l1: 0.482116
# [1000]	training's l1: 4.07288	valid_1's l1: 0.444509
# [1500]	training's l1: 3.92238	valid_1's l1: 0.405037
# [2000]	training's l1: 3.8507	valid_1's l1: 0.372074
# [2500]	training's l1: 3.78472	valid_1's l1: 0.369549
# Early stopping, best iteration is:
# [2435]	training's l1: 3.78978	valid_1's l1: 0.365325
# 7
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.12483	valid_1's l1: 0.354601
# [1000]	training's l1: 3.85645	valid_1's l1: 0.274504
# Early stopping, best iteration is:
# [1206]	training's l1: 3.79322	valid_1's l1: 0.264653
# 8
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [183]	training's l1: 4.5231	valid_1's l1: 0.425562
# 9
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [292]	training's l1: 4.34677	valid_1's l1: 0.310028
# Mean Absolute Error (MAE): 0.44455692296416605
# Mean Absolute Error (MAE) after postprocessing: 0.5635593220338984
# dt_train : 655 -> 642
# dt_train : 543 -> 642
# 0
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 0.6415	valid_1's l1: 0.0187812
# [1000]	training's l1: 0.640013	valid_1's l1: 0.0146022
# [1500]	training's l1: 0.63932	valid_1's l1: 0.0128607
# [2000]	training's l1: 0.638497	valid_1's l1: 0.012077
# [2500]	training's l1: 0.638265	valid_1's l1: 0.0115911
# Early stopping, best iteration is:
# [2740]	training's l1: 0.638205	valid_1's l1: 0.0114878
# 1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 0.645673	valid_1's l1: 0.0150832
# [1000]	training's l1: 0.642826	valid_1's l1: 0.011257
# [1500]	training's l1: 0.640689	valid_1's l1: 0.0055455
# [2000]	training's l1: 0.640105	valid_1's l1: 0.00470933
# Early stopping, best iteration is:
# [2093]	training's l1: 0.64002	valid_1's l1: 0.00425617
# 2
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 0
# [7000]	training's l1: 0.821178	valid_1's l1: 0.0139263
# [7500]	training's l1: 0.820864	valid_1's l1: 0.013518
# [8000]	training's l1: 0.82055	valid_1's l1: 0.0131627
# [8500]	training's l1: 0.820079	valid_1's l1: 0.0128137
# [9000]	training's l1: 0.81875	valid_1's l1: 0.0125135
# [9500]	training's l1: 0.818519	valid_1's l1: 0.012461
# Early stopping, best iteration is:
# [9704]	training's l1: 0.818497	valid_1's l1: 0.0124009
# 8
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 0.821306	valid_1's l1: 0.00699561
# [1000]	training's l1: 0.820081	valid_1's l1: 0.00485024
# [1500]	training's l1: 0.817243	valid_1's l1: 0.0041696
# [2000]	training's l1: 0.816101	valid_1's l1: 0.00361448
# [2500]	training's l1: 0.815839	valid_1's l1: 0.00323468
# [3000]	training's l1: 0.815673	valid_1's l1: 0.00307083
# [3500]	training's l1: 0.815497	valid_1's l1: 0.00280831
# [4000]	training's l1: 0.815294	valid_1's l1: 0.00264256
# [4500]	training's l1: 0.815143	valid_1's l1: 0.00254303
# [5000]	training's l1: 0.815024	valid_1's l1: 0.00242756
# [5500]	training's l1: 0.814896	valid_1's l1: 0.00237023
# [6000]	training's l1: 0.814794	valid_1's l1: 0.0023207
# Early stopping, best iteration is:
# [5860]	training's l1: 0.81483	valid_1's l1: 0.00231828
# 9
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 0.824174	valid_1's l1: 0.00968018
# [1000]	training's l1: 0.820521	valid_1's l1: 0.00848818
# [1500]	training's l1: 0.820226	valid_1's l1: 0.00824945
# Early stopping, best iteration is:
# [1795]	training's l1: 0.819872	valid_1's l1: 0.00814154
# Mean Absolute Error (MAE): 0.012224133779661337
# Mean Absolute Error (MAE) after postprocessing: 0.026836158192090395
# dt_train : 654 -> 642
# dt_train : 543 -> 642
# 0
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.19384	valid_1's l1: 0.572307
# Early stopping, best iteration is:
# [658]	training's l1: 4.11592	valid_1's l1: 0.550614
# 1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.16654	valid_1's l1: 0.631908
# [1000]	training's l1: 4.00858	valid_1's l1: 0.557563
# [1500]	training's l1: 3.93554	valid_1's l1: 0.532043
# Early stopping, best iteration is:
# [1329]	training's l1: 3.95567	valid_1's l1: 0.528452
# 2
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.23247	valid_1's l1: 0.702003
# [1000]	training's l1: 3.96554	valid_1's l1: 0.574671
# [1500]	training's l1: 3.88796	valid_1's l1: 0.510257
# [2000]	training's l1: 3.85961	valid_1's l1: 0.490767
# [2500]	training's l1: 3.8095	valid_1's l1: 0.481545
# [3000]	training's l1: 3.77324	valid_1's l1: 0.45786
# [3500]	training's l1: 3.75492	valid_1's l1: 0.450556
# Early stopping, best iteration is:
# [3745]	training's l1: 3.74538	valid_1's l1: 0.438976
# 3
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.13703	valid_1's l1: 0.438174
# Early stopping, best iteration is:
# [447]	training's l1: 4.18643	valid_1's l1: 0.412383
# 4
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.1271	valid_1's l1: 0.546891
# [1000]	training's l1: 3.96432	valid_1's l1: 0.507616
# [1500]	training's l1: 3.86447	valid_1's l1: 0.497871
# [2000]	training's l1: 3.80818	valid_1's l1: 0.47714
# Early stopping, best iteration is:
# [2227]	training's l1: 3.79648	valid_1's l1: 0.46881
# 5
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [125]	training's l1: 4.54032	valid_1's l1: 0.57112
# 6
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.16554	valid_1's l1: 0.434596
# [1000]	training's l1: 3.97063	valid_1's l1: 0.423599
# [1500]	training's l1: 3.87294	valid_1's l1: 0.414028
# Early stopping, best iteration is:
# [1781]	training's l1: 3.85352	valid_1's l1: 0.411168
# 7
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.12977	valid_1's l1: 0.313973
# [1000]	training's l1: 3.99659	valid_1's l1: 0.301716
# Early stopping, best iteration is:
# [848]	training's l1: 4.02463	valid_1's l1: 0.295026
# 8
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.15019	valid_1's l1: 0.392205
# [1000]	training's l1: 3.98456	valid_1's l1: 0.359482
# Early stopping, best iteration is:
# [1171]	training's l1: 3.94574	valid_1's l1: 0.353686
# 9
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 4.20184	valid_1's l1: 0.42718
# [1000]	training's l1: 4.00612	valid_1's l1: 0.38868
# [1500]	training's l1: 3.92118	valid_1's l1: 0.375773
# [2000]	training's l1: 3.87406	valid_1's l1: 0.370961
# Early stopping, best iteration is:
# [2264]	training's l1: 3.84298	valid_1's l1: 0.364195
# Mean Absolute Error (MAE): 0.43967030382771566
# Mean Absolute Error (MAE) after postprocessing: 0.5141242937853108
# dt_train : 654 -> 642
# dt_train : 543 -> 642
# 0
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 5.97929	valid_1's l1: 0.891959
# Early stopping, best iteration is:
# [661]	training's l1: 5.88995	valid_1's l1: 0.857843
# 1
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.06003	valid_1's l1: 0.730379
# [1000]	training's l1: 5.79797	valid_1's l1: 0.666037
# [1500]	training's l1: 5.67749	valid_1's l1: 0.619954
# Early stopping, best iteration is:
# [1695]	training's l1: 5.64717	valid_1's l1: 0.611807
# 2
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.0195	valid_1's l1: 0.597908
# [1000]	training's l1: 5.78686	valid_1's l1: 0.546101
# Early stopping, best iteration is:
# [1206]	training's l1: 5.72108	valid_1's l1: 0.538239
# 3
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 5.97935	valid_1's l1: 0.446026
# Early stopping, best iteration is:
# [794]	training's l1: 5.80853	valid_1's l1: 0.401417
# 4
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.06538	valid_1's l1: 0.439423
# [1000]	training's l1: 5.80336	valid_1's l1: 0.353666
# Early stopping, best iteration is:
# [1095]	training's l1: 5.78399	valid_1's l1: 0.352973
# 5
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.01056	valid_1's l1: 0.610467
# Early stopping, best iteration is:
# [746]	training's l1: 5.84309	valid_1's l1: 0.58642
# 6
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.02919	valid_1's l1: 0.487825
# Early stopping, best iteration is:
# [434]	training's l1: 6.0922	valid_1's l1: 0.476844
# 7
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.04401	valid_1's l1: 0.421578
# Early stopping, best iteration is:
# [493]	training's l1: 6.04852	valid_1's l1: 0.418669
# 8
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 6.06492	valid_1's l1: 0.471465
# [1000]	training's l1: 5.78206	valid_1's l1: 0.45866
# Early stopping, best iteration is:
# [1128]	training's l1: 5.74368	valid_1's l1: 0.454061
# 9
# Training until validation scores don't improve for 200 rounds
# [500]	training's l1: 5.95173	valid_1's l1: 0.576168
# [1000]	training's l1: 5.75388	valid_1's l1: 0.514734
# Early stopping, best iteration is:
# [1238]	training's l1: 5.69324	valid_1's l1: 0.503792
# Mean Absolute Error (MAE): 0.5203231522627272
# Mean Absolute Error (MAE) after postprocessing: 0.576271186440678
# Typhoid mae score : 0.07810221746193041
# Diarrhea mae score : 0.4797579862023834
# Malaria mae score : 0.37322579944768797
# Schistosomiasis mae score : 0.011130186381798681
# Intestinal Worms mae score : 0.40561146409651694
